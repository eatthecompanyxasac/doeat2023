# %%
import pandas as pd
import numpy as np
import os

# %%
# 리뷰 출력시 ... 없이 전부 나오게 설정
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 데이터 불러오기
# - 네이버 쇼핑 리뷰데이터
# - 네이버 지식인 데이터

# %%
naver_shopping = pd.read_csv(r"C:\Users\NT550\asac\SIH\SIH\code2\code\naver_shopping.csv", index_col=0)
naver_brain = pd.read_excel(r"C:\Users\NT550\asac\SIH\SIH\code2\code\네이버지식인.xlsx", index_col=0)

# %%
""" # 키워드 정제한 파일 업로드

data_dir = r'C:\Users\NT550\asac\SIH\SIH\eat_the\file\키워드 정제'
data_list = os.listdir(data_dir) """
# Out:
#   Cell In[4], line 4
#     data_list = os.listdir(data_dir) """
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 133-134: truncated \UXXXXXXXX escape

# %%
naver_shopping.head()
# Out:
#    Unnamed: 0                                                 제품명      가격  \
# 0           0  허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발  72,000
# 1           1  허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발  72,000
# 2           2  허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발  72,000
# 3           3  허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발  72,000
# 4           4  허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발  72,000
#
#    평균평점          아이디   평점         날짜  \
# 0   4.9  miri*******  5.0  23.08.16.
# 1   4.9    dltm*****  5.0  23.07.28.
# 2   4.9     yjdr****  5.0  23.08.06.
# 3   4.9      2133***  5.0  23.07.13.
# 4   4.9     klys****  5.0  23.08.12.
#
#                                                 종류                       요약  \
# 0  30포 선택1: 아카시아 / 30포 선택2: 아카시아 / 30포 선택3: 아카시아\n  유통기한아주 넉넉해요포장꼼꼼해요편리편리해요
# 1           30포 선택1: 밤 / 30포 선택2: 밤 / 30포 선택3: 밤\n   유통기한꽤 남았어요포장꼼꼼해요편리편리해요
# 2    30포 선택1: 올인원 / 30포 선택2: 올인원 / 30포 선택3: 아카시아\n   유통기한꽤 남았어요포장꼼꼼해요편리편리해요
# 3       30포 선택1: 밤 / 30포 선택2: 야생화 / 30포 선택3: 올인원\n  유통기한아주 넉넉해요포장꼼꼼해요편리편리해요
# 4      30포 선택1: 야생화 / 30포 선택2: 밤 / 30포 선택3: 아카시아\n  유통기한아주 넉넉해요포장꼼꼼해요편리편리해요
#
#                                                                                                                                                                                                                                      리뷰  \
# 0                                                                                                                                                        한달사용기재구매먹기 편하고 품질도 좋아요. 받는 손님도 좋아 하시고 구매등급도 따로 있어서 좋아요. 문제 생기면 바로 처리 해주시고 좋아요!
# 1                                                                      간편하게 하루한포씩먹게되요~냉장이나 냉동으로 해서 시원하게 먹으니 맛잇어요!!밤꿀이 많이 쓸줄알앗는데 쓴건 잘 안먹는편이기도 하구요  생각보다 진하니 먹을만했어요 요즘 면역이 많이 떨어지기도 했고 겸사겸사 구매했는데 마음에들어서 다음에 재구매해야겠어요! 선물용으로도 너무 좋을거 같아요!
# 2                                                                                                     홍삼이 여자몸에 안좋다고해서.. 그동안 안먹다가 꿀 스틱 보고 주문했습니다\n당떨어지기전에 먹으면 좋구요 밖에서도 쉽게 먹을수있어요. 이지컷이 잘 뜯어집니다.\n캡슐커피 내려먹을때 넣어먹을수도 있네요\n다먹으면 또 주문하려구요 ㅎㅎ
# 3  BEST꿀이 피로 회복, 기관지에 좋다고 하는데 사실 어느정도가 적당한지, 너무 많이 먹으면 안좋은 건 아닌지 고민되더라구요ㅠ\n특히 부모님께 선물할 건데 꿀 많이 드셔서 당 수치가 올라갈까봐 걱정됬었는데 소량으로 먹기 좋게 스틱 포장 되어있어서 좋아요 !\n병에 담긴 꿀은 매일 꺼내서 떠먹기가 불편하고 적정량을 먹는건지 긴가민가했는데 부모님도 편하게 잘 드시고 계셔서 너무 만족스러운 선물이었습니다 💚💚💚
# 4                                                                                                                                                                         한달사용기진짜 꿀이예요. 예전 시골에서 먹던 꿀맛과 같아요. 술먹고 먹어도 숙취에도 좋아요. 또 구매할거예요.
#
#                                                                                                                                                                                                                 ko_review
# 0                                                                                                                                             한달사용기재구매먹기 편하고 품질도 좋아요 받는 손님도 좋아 하시고 구매등급도 따로 있어서 좋아요 문제 생기면 바로 처리 해주시고 좋아요
# 1                                                             간편하게 하루한포씩먹게되요냉장이나 냉동으로 해서 시원하게 먹으니 맛잇어요밤꿀이 많이 쓸줄알앗는데 쓴건 잘 안먹는편이기도 하구요  생각보다 진하니 먹을만했어요 요즘 면역이 많이 떨어지기도 했고 겸사겸사 구매했는데 마음에들어서 다음에 재구매해야겠어요 선물용으로도 너무 좋을거 같아요
# 2                                                                                                 홍삼이 여자몸에 안좋다고해서 그동안 안먹다가 꿀 스틱 보고 주문했습니다당떨어지기전에 먹으면 좋구요 밖에서도 쉽게 먹을수있어요 이지컷이 잘 뜯어집니다캡슐커피 내려먹을때 넣어먹을수도 있네요다먹으면 또 주문하려구요 ㅎㅎ
# 3  꿀이 피로 회복 기관지에 좋다고 하는데 사실 어느정도가 적당한지 너무 많이 먹으면 안좋은 건 아닌지 고민되더라구요ㅠ특히 부모님께 선물할 건데 꿀 많이 드셔서 당 수치가 올라갈까봐 걱정됬었는데 소량으로 먹기 좋게 스틱 포장 되어있어서 좋아요 병에 담긴 꿀은 매일 꺼내서 떠먹기가 불편하고 적정량을 먹는건지 긴가민가했는데 부모님도 편하게 잘 드시고 계셔서 너무 만족스러운 선물이었습니다
# 4                                                                                                                                                               한달사용기진짜 꿀이예요 예전 시골에서 먹던 꿀맛과 같아요 술먹고 먹어도 숙취에도 좋아요 또 구매할거예요

# %%
""" # 제품별 중요 키워드 추출하는 함수

def table_view(n):
    df = pd.read_excel(data_dir+'/'+data_list[n], index_col=0).dropna()
    print(data_list[n])
    print(df) """

# %%
# 제품별 리뷰 추출하는 함수

def kw_in_product(product_name, keyword):
    return naver_shopping[(naver_shopping['제품명'] == product_name)&(naver_shopping['ko_review'].apply(lambda x:keyword in x))]['ko_review']

# %%
naver_shopping['제품명'].head()
# Out:
# 0    허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발
# 1    허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발
# 2    허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발
# 3    허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발
# 4    허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트 [원산지:국산]오늘출발
# Name: 제품명, dtype: object

# %%
naver_shopping['ko_review'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 57141 entries, 0 to 57140
# Series name: ko_review
# Non-Null Count  Dtype
# --------------  -----
# 55763 non-null  object
# dtypes: object(1)
# memory usage: 892.8+ KB

# %%
type(naver_shopping['제품명'].unique()[10])
# Out:
# str

# %%
kw_in_product(naver_shopping['제품명'], '간편')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 len(kw_in_product(naver_shopping['제품명'], '간편'))
#
# Cell In[6], line 4, in kw_in_product(product_name, keyword)
#       3 def kw_in_product(product_name, keyword):
# ----> 4     return naver_shopping[(naver_shopping['제품명'] == product_name)&(naver_shopping['ko_review'].apply(lambda x:keyword in x))]['ko_review']
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[6], line 4, in kw_in_product.<locals>.<lambda>(x)
#       3 def kw_in_product(product_name, keyword):
# ----> 4     return naver_shopping[(naver_shopping['제품명'] == product_name)&(naver_shopping['ko_review'].apply(lambda x:keyword in x))]['ko_review']
#
# TypeError: argument of type 'float' is not iterable

# %% [markdown]
# ### 구성원 라벨링
# - 비슷한 의미를 합쳐줌

# %%
# 구성원 라벨링

who_dad =['아빠','아버지','아부지'] # 0
who_mam = ['엄마','어머니']         # 1
who_husband = ['남편','오빠', '남의편','아저씨'] # 2
who_guest = ['손님','직장','친구','남친'] # 3
who_kid = ['딸','아들','아이','애들','얘들'] # 4
who_baby = ['아기','애기'] # 5
who_fam = ['식구','가족'] # 6
who_parents = ['부모','엄빠'] # 7

# %%
data_kurly['person_label'] = data_kurly['ReviewText'].apply(lambda text: 
                                                        0 if any(word in text for word in who_dad) else
                                                        1 if any(word in text for word in who_mam) else
                                                        2 if any(word in text for word in who_husband) else
                                                        3 if any(word in text for word in who_guest) else
                                                        4 if any(word in text for word in who_kid) else
                                                        5 if any(word in text for word in who_baby) else
                                                        6 if any(word in text for word in who_fam) else
                                                        7 if any(word in text for word in who_parents) else np.nan)

# %% [markdown]
# ### 목적(상황)라벨링
# - 비슷한 상황이나 목적을 하나로 합쳐줌

# %%
# 목적 라벨링

invite = ['집들이', '초대', '접대', '파티', '해드', '파티', '크리스마스', '대접', '생일', '생신', '손님','모실때', '모시', '어르신', '어루신'] # 0
goodmeal = ['보신', '분위기', '고급', '건강', '보양', '도전', '기운', '기분','제대로','성공'] # 1
comfortable = ['귀찮','편하','급하','간단','밥하기','입맛없','입맛 없','밥맛없','밥맛 없','반찬없','반찬 없','바쁜','바쁠','바쁘'] # 2
gift = ['선물','드렸','보내','보냈'] # 3

# %%
data_kurly['perpose_label'] = data_kurly['ReviewText'].apply(lambda text: 
                                                        0 if any(word in text for word in invite) else
                                                        1 if any(word in text for word in goodmeal) else
                                                        2 if any(word in text for word in who_husband) else
                                                        3 if any(word in text for word in comfortable) else
                                                        4 if any(word in text for word in gift) else np.nan)

# %%
# csv 파일 생성
# data_kurly.to_csv('컬리_라벨링.csv')

# %%
df = pd.read_excel(r'C:\Users\NT550\asac\SIH\SIH\eat_the\kurly_label.xlsx')

# %%
df[df['purpose_label'] == 5].head()

# %% [markdown]
# ## 시각화

# %%
import matplotlib.pyplot as plt

# 'person_label' 컬럼에서 7을 제외한 데이터를 새로운 DataFrame으로 생성합니다.
data_kurly_filtered = df[df['person_label'] != 7]

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# 라벨 매핑 딕셔너리
label_mapping = {
    1: '외부인',
    2: '어른',
    3: '아이',
    4: '부부',
    5: '가족',
    6: '혼자'
}

# 각 라벨의 빈도수를 계산합니다.
label_counts = data_kurly_filtered['person_label'].value_counts()

# 막대 그래프를 그립니다.
plt.figure(figsize=(8, 6))
plt.bar([label_mapping[label] for label in label_counts.index], label_counts.values)
plt.xlabel('Person Label')  # x축 라벨 설정
plt.ylabel('빈도수')  # y축 라벨 설정
plt.title('사람 라벨 빈도수 (막대 그래프)')  # 그래프 제목 설정
plt.show()

# 파이 차트를 그립니다.
plt.figure(figsize=(8, 8))
plt.pie(label_counts.values, labels=[label_mapping[label] for label in label_counts.index], autopct='%1.1f%%')
plt.title('사람 라벨 빈도수 (파이 차트)')  # 그래프 제목 설정
plt.axis('equal')  # 파이 차트가 원형으로 그려지도록 설정
plt.show()

# %%
# 0값을 제외한 나머지 값의 빈도수 계산
filtered_data = df[df['purpose_label'] != 0]['purpose_label']
value_counts = filtered_data.value_counts()

# 라벨 매핑 딕셔너리
label_mapping = {
    1: '선물',
    2: '대접',
    3: '제대로 먹기',
    4: '간편하게',
    5: '제대로+간편히'
}

# 막대 그래프 그리기
plt.figure(figsize=(8, 6))
plt.bar([label_mapping[label] for label in value_counts.index], value_counts.values)
plt.xlabel('목적 라벨')  # x축 라벨 설정
plt.ylabel('빈도수')  # y축 라벨 설정
plt.title('사람 라벨 빈도수 (막대 그래프)')  # 그래프 제목 설정
plt.show()

# 파이 차트 그리기 (이 부분은 변경하지 않습니다)
plt.figure(figsize=(8, 8))
plt.pie(value_counts.values, labels=[label_mapping[label] for label in value_counts.index], autopct='%1.1f%%')
plt.title('목적 라벨 비율 (파이차트)')
plt.show()

# %% [markdown]
# ### 목적(purpose_label)에 따른 사람(person_label)리뷰 확인

# %%
""" 
1. 편하게 - 아이 4 -3
2. 편하게 - 혼자 4 - 6
3. 편하게 - 그 외 가족 4 -5
4. 초대 - 손님 2 - 1
5. 초대 - 어른 2 - 2
6. 초대 - 부부 2 - 4
7. 선물 - 어른 1 - 2
8. 선물 - 손님 1 - 1
9. 선물 - 그외가족 1 - 5 
10. 제대로 - 아이 3 - 3
11. 제대로 - 혼자 3 - 6
12. 제대로 - 어른 3 - 2
"""

df[(df['purpose_label'] == 3) & (df['person_label'] == 6)]['ReviewText']
# Out:
# 197                                                                                                                                                                                                                                                                                                                                                                                   솥밥먹고싶어서 르쿠르제까지 구매했는데 제가 시간조절못한건지 설익어서 무지 아쉽네요 잘만 하면 맛있게 먹을 수 있을 거 같은데 재도전하긴 두렵네요
# 377                                                                                                                                                                                                                                                                                                                                                                                                                            솥밥 어렵 ㅠㅠ 담에 다시 도전할래요 제가 문제지 구성 자체는 알찼어요
# 1026                                                                                                                                                                                                                                              상품설명에 나와있는거 보고 그대로 냄비밥에 도전해봤는데, 타지않고 성공했어요. 해물은 더 추가하지않고 했는데, 먹으면서 집에 있는 해물 점 더 추가할껄 후회했어요. 해물 있으면 무조건 추가하세요!  짜다는 후기가 많아서 육수 전부 쓰지않고, 생수 좀 더 첨가했는데, 먹어보니 그냥 먹어도 될 정도더라구요. 양념장 넣어서 먹으면 더 맛이 있습니다. 저는 나중에 자주문 할 것같아요.
# 2218                                                                                                                                                                                                             무슨맛일까 싶어서 조리하면서 한입 떠먹었는데 완전 레스토랑맛 나서 감동 했어요!  사실 밀키트 제품을 저는 바로바로 냉동고에서 꺼내 먹는지라   1. 찍어먹는 소스만 제대로 유수해동 2. 같이 끓이는 소스는 대강 유수해동해서 조각내서 같이 끓여버립니다.  뜨거울때 > 따뜻할때 > 식었을때 모두 맛이 다르더라구요. 뜨거울때가 최고로 맛있어요. 풍미가 아주 좋아요. 식을수록 크림스프에 밥말아 먹은감이 좀 있지만은~  재구매 의사 있습니다.
# 5741                                                                                                                                                                                                                                                                                                                                                                                                  가성비좋고 맛있어요. 솥밥왕창사서 매일 먹는데 ㅎㅎ저는 힘많이 안들이고 맛있는솥밥을 식탁위에 올리니 기분이 좋네요.
# 5775                                                                                                                                                                                                                                                                                                                                                                                솥밥 처음인데 레시피 대로 했더니 대성공 입니다!! 저는 가리비까지 추가해서  2명이서 배부르게 먹었어요 적당히 눌러서 끝까지 맛있게 먹었습니다bb
# 7073                                                                                                                                                                                                                                                                                                                                                                             첫 솥밥 성공♥️♥️ 넘맛있는데 양이 매우 적어서 저는 한우 국거리 추가해서 사고 쌀도 추가해서 더 넣었더니 2인분 됬어요~  재구매 의사 있습니다!!!
# 7678                                                                                                                                                                                                                          저는 늘 솥밥을 실패했었는데 이번에 밀키트론 대성공했어요!! 현미로 해서 그랬던건진 모르겠지만, 수린 밀키트는 흰쌀이라 많이 불릴필요가 없어 쉽게 조리가 가능했어요! 슴슴하다는 이야기가 많아 저는 집에 있는 쯔유를 따로 한스푼 넣어서 조리를 했고 고기도 버터에 굽굽, 그리고 계란 노른자를 넣어 비벼주었어요! 따로 밥반찬 및 양념이 없어도 너무 맛있었고 둘이서 너무 맛있게 먹었답니다! :) 저는 재구매의사 있어요!
# 7898                                                                                                                                                                                                                                                                                                                                                                                                                               제 입에는 조금 싱거운 느낌이였어여 건강한밥상  고기도 맛났어요
# 8373                                                                                                                                                                                                                                                                                                                                                         재구매할고예요 ..! 제가 못찾은 걸 수도 있는데 온하루꺼만 유일하게 국산이더라고요 , 집에있는 톳만 조금 더 넣어 밥했는데 재료도 푸짐하고요 삼삼하니 건강한 한끼식사 했습니다 또 살거예요
# 8410                                                                                                                                                                                                                                                                                                                                 준비하면서도 과연 이게 맛있을까 의심이 들었는데 결과는 대만족입니다~ 간도 삼삼하니 넘 맛나요 다만 전기밥솥으로 했는데 제가 물을 너무 많이 넣었는지 죽밥이 되긴했습니다 흑흑 그래도 넘 맛나서 재구매 의사 있습니다 담엔 꼭 성공하리
# 8414                                                                                                                                                                                                                                                                                              구운 생선이라 받자마자 바로 해서 먹어야 좋을 것 같아요. 맛은 딱 건강해지는 맛이에요. 저는 특히 토마토가 너무 맛있었어요. 자극적인 맛에 익숙해진 사람은 별로 안 좋아할 수도..? 근데 솔직히 구성에 비해 가격이 쎈 것 같다는 생각이 들어서 세일할 때 아니면 굳이 구매할 것 같지는 않아요.
# 8978                                                                                                                                                                                                                                                    미쳤어요.. 이 가격에 이런 퀄리티라니.. 제 입맛엔 ㅈㅁㅌ입니다(제취향은 갈치속젓까지ok, 고래고기/돔베기ok) 쿰쿰한 냄새가 돔베기같아서 그러려니합니다 맨날 할인 했음 좋겠어요ㅠㅠ 어제 사먹고 식단하려고하는데 또 할인해서 고민중이에요.. 쪽파 넉넉히 추가, 다시마 네장이랑 맛술 한큰술넣고 밥했더니 정신잃고 흡입했습니다 할인 자주했음 좋겠어요 취향저격 제대로 했슴다
# 9179                                                                                                                                                                                                                                                                                                                                                                                                          저는 불호. 상했나 싶은 불쾌한 향이 났어요 ㅠ  기대했는데 아쉽 다음엔 미나리 솥밥 도전해볼게요 ㅠ
# 9401     생선요리 도전하고싶은신 분들께 강추:)  밀키트 그대로 조리보단 밥지으실때 다시마 한조각 맛술1T넣고 같이 지으세요 비린맛이 싹 줄어듭니다! 저는 전기밥솥으로 조리했고 참기를 바른 뚝배기오 옮겨담아 최대한 약불로 5분정도 두시면 밑에 누룽지 생기면서 참기름발라서 뒤처리도 깔끔합니다~처음부터 솥밥하시기 어려우면 이방법 추천드려요 타서 못먹거나 눌러붙지도 않아서 강추!!그다음에 대파를 왕창썰어서 고명으로 올려주시고 기호에따라 계란 톡! 저는 명란곁들여서 우아하게 먹었습니다 흐흐 도미는 초간장에 살짝 찍어서 명란 올려서 먹으면 일식집 안부럽습니다.   명란양념-명란1개.다진마늘0.5T.통깨1T.고춧가루한꼬집.청양고추1개다진것.후추약간(같이 드셔보세요 저세상맛)  초간장-양조간장2T.식초2T.설탕0.5T.통깨0.5.물3T.쪽파2T.청양고추다진것1T.미원한꼬집(맛집에서먹는 그 소스맛이납니다ㅋㅋ)
# 11693                                                                                                                                                                                                                                                                                                          솥밥 사려고 주물냄비를 샀는데 첨엔 키트로 해봐야겠다 싶어서 냄비 게시용으로 구매했습니당 생각보다 간은 삼삼하지만 건강한 미나리 얹어 먹으니 속도 따뜻하고 든든하니 좋네용 (저는 부추도 좀 추가해서 넣었어요) 솥밥 첨 도전하신다면 한번 키트 사서 해보시는 것도 좋을듯해유
# 12107                                                                                                                                                                                                                                                                                                                                                                                                                                        후기보고 샀는데 저는 별로였어요 너무 건강한맛
# Name: ReviewText, dtype: object
