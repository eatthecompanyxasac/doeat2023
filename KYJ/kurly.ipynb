# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://api.kurly.com/product-review/v2/contents-products/1000098225/reviews?sortType=RECOMMEND&size=100000&onlyImage=false'
res = requests.get(url,  headers=header)
data = res.json()
data
# Out:
# {'data': [{'no': 84739049,
#    'type': '베스트',
#    'contents': '얼마전 옆에 언니를 통해서 알게된 문어솥밥.\n너무 맛있어서 마켓컬리에서 주문해보았습니다.문어솥밥이랑 해물솥밥이랑 각각 하나씩 주문을 했답니다. 해물솥밥에는 굴, 새우, 가리비등이 들어있었고 버섯과 톳도 들어있었는데\n해산물이 냉동이었지만 냉동인지 모를만큼 맛있었습니다.마법의 육수.이 육수의 정체가 궁금했습니다. 전기밥솥에 해도 되는데 언니가 일반 압력밥솥에 하면 더 맛있다고 하서 밥솥에 했는데 밥이 쫀득하고 간이 너무 잘되어 밥이 계속들어갑니다^^ 추가로 밥에 넣어 비비는 간장은 절대 많이 넣으시면 안됩니다.\n아주 조금 넣어 비벼드셔야 됩니다.\n저는 참고로 소스 안넣고 조미김에 싸먹었습니다.문어솥밥도 해먹어보고 후기 올리겠습니다.\n재구매의사 있습니다.',
#    'dealProductNo': 1000098224,
#    'dealProductName': '[아우름] 바다를 품은 톳 해물솥밥키트',
#    'contentsProductNo': 1000098225,
#    'contentsProductName': '[아우름] 바다를 품은 솥밥키트 2종 (냉동) (택1)',
#    'likeCount': 27,
#    'isLike': False,
#    'visibility': 'PUBLIC',
#    'ownerGrade': '일반',
#    'ownerName': '박**',
#    'registeredAt': '2023-03-09T04:47:37.341149',
#    'modifiedAt': '2023-03-09T04:50:09',
#    'ownerProfiles': {'beautyProfile': '', 'marketProfile': ''},
#    'productImageUrl': '',
#    'images': [{'no': 44426252,
# ...

# %%
len(data['data'])
# Out:
# 52

# %%
data['data'][2]
# Out:
# {'no': 96967376,
#  'type': '일반',
#  'contents': '맛있어서 재구매했어요',
#  'dealProductNo': 1000104564,
#  'dealProductName': '[아우름] 바다를 품은 문어솥밥키트',
#  'contentsProductNo': 1000098225,
#  'contentsProductName': '[아우름] 바다를 품은 솥밥키트 2종 (냉동) (택1)',
#  'likeCount': 0,
#  'isLike': False,
#  'visibility': 'PUBLIC',
#  'ownerGrade': '프렌즈',
#  'ownerName': '태**',
#  'registeredAt': '2023-07-05T07:37:40.893328',
#  'modifiedAt': '2023-07-05T07:37:40.893328',
#  'ownerProfiles': {'beautyProfile': '', 'marketProfile': ''},
#  'productImageUrl': '',
#  'images': [{'no': 48390490,
#    'image': 'https://img-cf.kurly.com/cdn-cgi/image/width=640,height=640,quality=90/shop/data/review/20230705/23f86c1b-9954-43ae-85a9-8a2dbd1b5225.jpg'}],
#  'comments': []}

# %%
header = {
'Authority': 'api.kurly.com',
'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'ko,en;q=0.9,en-US;q=0.8',
'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..suXIwLxozEbaRJGnVFG-LR4LDeremNI0wpdVPQHf19k',
'Origin': 'https://www.kurly.com',
'Sec-Ch-Ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Microsoft Edge";v="114"',
'Sec-Ch-Ua-Mobile': '?0',
'Sec-Ch-Ua-Platform': '"Windows"',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 Edg/114.0.1823.67'}

# %%
goodsno = 1000098225
af = 'MC4wOjE2ODg0MjE4MzUwMzQ'
reviewpage = f'https://api.kurly.com/product-review/v2/contents-products/1000098225/reviews?sortType=RECENTLY&size=1000'
res = requests.get(reviewpage, headers=header)
data = res.json()

# %%
data
# Out:
# {'error': {'message': 'Token has expired', 'code': '1002'},
#  'code': '1002',
#  'message': 'Token has expired'}

# %%
goodsno = 1000098225
af = 'MC4wOjE2ODg0MjE4MzUwMzQ'
reviewpage = f'https://api.kurly.com/product-review/v2/contents-products/1000098225/reviews?sortType=RECOMMEND&size=10000&onlyImage=false'
res = requests.get(reviewpage, headers=header)
data = res.json()

# %%
len(data['data'][0])
# Out:
# 18

# %%
header = {
'Authority': 'api.kurly.com',
'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'ko,en;q=0.9,en-US;q=0.8',
'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..20fPDFLYd-m043Ff9fGfROCaVs-5L36DpzPUbRDZvWg',
'Origin': 'https://www.kurly.com',
'Sec-Ch-Ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Microsoft Edge";v="114"',
'Sec-Ch-Ua-Mobile': '?1',
'Sec-Ch-Ua-Platform': "Android",
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 Edg/114.0.1823.67'}

# %%
reviewpage = 'https://api.kurly.com/product-review/v2/contents-products/1000098225/reviews?sortType=RECENTLY&size=1000'
res = requests.get(reviewpage, headers=header)
data = res.json()

# %%
data
# Out:
# {'data': [{'no': 96967376,
#    'type': '일반',
#    'contents': '맛있어서 재구매했어요',
#    'dealProductNo': 1000104564,
#    'dealProductName': '[아우름] 바다를 품은 문어솥밥키트',
#    'contentsProductNo': 1000098225,
#    'contentsProductName': '[아우름] 바다를 품은 솥밥키트 2종 (냉동) (택1)',
#    'likeCount': 0,
#    'isLike': False,
#    'visibility': 'PUBLIC',
#    'ownerGrade': '프렌즈',
#    'ownerName': '태**',
#    'registeredAt': '2023-07-05T07:37:40.893328',
#    'modifiedAt': '2023-07-05T07:37:40.893328',
#    'ownerProfiles': {'beautyProfile': '', 'marketProfile': ''},
#    'productImageUrl': '',
#    'images': [{'no': 48390490,
#      'image': 'https://img-cf.kurly.com/cdn-cgi/image/width=640,height=640,quality=90/shop/data/review/20230705/23f86c1b-9954-43ae-85a9-8a2dbd1b5225.jpg'}],
#    'comments': []},
#   {'no': 96952346,
#    'type': '일반',
#    'contents': '톳과 문어의 조합이 너무 좋아요 맛있어요',
#    'dealProductNo': 1000104564,
#    'dealProductName': '[아우름] 바다를 품은 문어솥밥키트',
#    'contentsProductNo': 1000098225,
# ...

# %%
len(data['data'][0])
# Out:
# 18

# %% [markdown]
# # 셀레니움

# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import re
import time

# %%
keyword = '솥밥'
url_goodsno = f'https://www.kurly.com/search?sword={keyword}&page=1&filters=category%3A911006'
path = r"C:/Users/NT550-048/Desktop/chromedriver.exe"
s = Service(path)
driver = webdriver.Chrome(service=s)
driver.get(url_goodsno)

# %%
keyword = '솥밥'
url_goodsno = f'https://www.kurly.com/search?sword={keyword}&page=1&filters=category%3A911006'
path = r"C:/Users/NT550-048/Desktop/chromedriver.exe"
s = Service(path)
driver = webdriver.Chrome(service=s)
driver.get(url_goodsno)
goodsno = []
num_goods = int(re.findall(r'\d+', driver.find_element(By.XPATH, '/html/body/div/div[3]/div/div/div/div[2]/div[1]/div').text)[0])
goodsno_list(num_goods)
review = []
for good in goodsno:
    review_list(good, review)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[70], line 12
#      10 review = []
#      11 for good in goodsno:
# ---> 12     review_list(good, review)
#
# Cell In[69], line 32, in review_list(good, review)
#      30     review.append([good, grade, name, menu, review_txt, review_date, like])
#      31 if _ != (page_review-1):
# ---> 32     driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[14]/button[2]').click()
#      33     time.sleep(1)
#
# File c:\Users\NT550-048\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# ...

# %% [markdown]
# ## 상품코드추출함수

# %%
def goodsno_list(num_goods):
    # 상품 페이지 수 계산
    if num_goods % 12 == 0:
        goods_page = num_goods / 12
    else:
        goods_page = int(num_goods / 12) + 1
    # 상품코드 추출
    for page_no in range(1, goods_page+1):
        url_goodsno = f'https://www.kurly.com/search?sword={keyword}&page={page_no}&filters=category%3A911006'
        driver.get(url_goodsno)
        time.sleep(1)
        if page_no == goods_page:
            for num in range(1, (num_goods%12)+1):
                goodsno_num = re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div[3]/div/div/div/div[2]/div[3]/a[{num}]').get_attribute('href'))[0]
                goodsno.append(goodsno_num)
        else:
            for num in range(1, 10):
                goodsno_num = re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div[3]/div/div/div/div[2]/div[3]/a[{num}]').get_attribute('href'))[0]
                goodsno.append(goodsno_num)

# %% [markdown]
# # 리뷰추출함수

# %%
# 제품별 리뷰 추출
def review_list(good, review):
    url = f'https://www.kurly.com/goods/{good}'
    driver.get(url)
    time.sleep(4)
    # 최근순
    driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[1]/div/button[2]').click()
    time.sleep(1)
    # 리뷰 수 추출
    review_tot_temp = re.findall(r'\d+', driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/nav/ul/li[3]/a/span[2]').text)
    review_tot = int(''.join(review_tot_temp))
    review_in_page = 10
    if review_tot%10 == 0:
        page_review = int(review_tot/10)
        lastpage_review = 10
    else:
        page_review = int(review_tot/10) + 1
        lastpage_review = review_tot%10
    # 크롤링
    for _ in range(page_review):
        if _ == (page_review-1):
            review_in_page = lastpage_review
        for n in range(4, 4+review_in_page):
            grade = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/div/div/span[1]').text
            name = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/div/div/span[2]').text
            menu = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/div/h3').text
            review_txt = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/p').text
            review_date = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/footer/div/span').text
            try:
                like = int(re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/footer/button/span[2]').text)[0])
            except:
                like = 0
            review.append([good, grade, name, menu, review_txt, review_date, like])
        if _ != (page_review-1):
            driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[14]/button[2]').click()
            time.sleep(1)

# %%
review = []
review_list(5131430, review)

# %%
len(review)
# Out:
# 339

# %%
review_df_9 = pd.DataFrame(review, columns = ['ProductCode', 'MemberGrade', 'MemberName', 'ProductName', 'ReviewText', 'ReviewDate', 'ReviewLike'])

# %%
review_df_9.to_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5131430.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)

# %%
review_df_9
# Out:
#      ProductCode MemberGrade MemberName        ProductName  \
# 0        5131430         화이트        김**  [온하루] 한돈 건나물 솥밥키트
# 1        5131430         라벤더        라**  [온하루] 한돈 건나물 솥밥키트
# 2        5131430         라벤더        이**  [온하루] 한돈 건나물 솥밥키트
# 3        5131430         라벤더        성**  [온하루] 한돈 건나물 솥밥키트
# 4        5131430         화이트        김**  [온하루] 한돈 건나물 솥밥키트
# ..           ...         ...        ...                ...
# 334      5131430          퍼플        성**  [온하루] 한돈 건나물 솥밥키트
# 335      5131430         더퍼플        최**  [온하루] 한돈 건나물 솥밥키트
# 336      5131430          퍼플        강**  [온하루] 한돈 건나물 솥밥키트
# 337      5131430         더퍼플        최**  [온하루] 한돈 건나물 솥밥키트
# 338      5131430          일반        김**  [온하루] 한돈 건나물 솥밥키트
#
#                                             ReviewText  ReviewDate  ReviewLike
# 0                                          컬리 최애 솥밥입니다  2023.05.21           0
# 1                                       온하루 솥밥 맛있었어요~~  2023.05.19           0
# ...

# %% [markdown]
# # 데이터 병합

# %%
df1 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_1000098225.csv')
df2 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_1000085960.csv')
df3 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5075632.csv')
df4 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_1000120077.csv')
df5 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5131316.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)
df6 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5131428.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)
df7 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5115304.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)
df8 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5067862.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)
df9 = pd.read_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5131430.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)

# %%
data_kurly = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9])

# %%
data_kurly.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data_kurly.to_csv('C:/Users/NT550-048/Desktop/잇더/data/data_kurly.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)

# %%
data_kurly.reset_index(inplace=True)

# %%
data_kurly.drop('index', axis=1, inplace=True)

# %%
data_kurly
# Out:
#        ProductCode MemberGrade MemberName            ProductName  \
# 0       1000098225          일반        송**  [아우름] 바다를 품은 톳 해물솥밥키트
# 1       1000098225          일반        봉**    [아우름] 바다를 품은 문어솥밥키트
# 2       1000098225         화이트        최**  [아우름] 바다를 품은 톳 해물솥밥키트
# 3       1000098225         라벤더        곽**  [아우름] 바다를 품은 톳 해물솥밥키트
# 4       1000098225         화이트        김**  [아우름] 바다를 품은 톳 해물솥밥키트
# ...            ...         ...        ...                    ...
# 12431      5131430          퍼플        성**      [온하루] 한돈 건나물 솥밥키트
# 12432      5131430         더퍼플        최**      [온하루] 한돈 건나물 솥밥키트
# 12433      5131430          퍼플        강**      [온하루] 한돈 건나물 솥밥키트
# 12434      5131430         더퍼플        최**      [온하루] 한돈 건나물 솥밥키트
# 12435      5131430          일반        김**      [온하루] 한돈 건나물 솥밥키트
#
#                                               ReviewText  ReviewDate  \
# 0                                         간단한 한끼대용으로 좋네요  2023.07.12
# ...

# %% [markdown]
# # backup

# %%
    # 최근순
    driver.execute_script("window.scrollBy(0, 12000);") # 스크롤이동
    time.sleep(0.5)
    driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[1]/div/button[2]').click()
    time.sleep(1)

# %%
keyword = '솥밥'
url_goodsno = f'https://www.kurly.com/search?sword={keyword}&page=1&filters=category%3A911006'
path = r"C:/Users/NT550-048/Desktop/chromedriver.exe"
s = Service(path)
driver = webdriver.Chrome(service=s)
driver.get(url_goodsno)
goodsno = []
num_goods = int(re.findall(r'\d+', driver.find_element(By.XPATH, '/html/body/div/div[3]/div/div/div/div[2]/div[1]/div').text)[0])
# 상품 페이지 수 계산
if num_goods % 12 == 0:
    goods_page = num_goods / 12
else:
    goods_page = int(num_goods / 12) + 1
# 상품코드 추출
for page_no in range(1, goods_page+1):
    url_goodsno = f'https://www.kurly.com/search?sword={keyword}&page={page_no}&filters=category%3A911006'
    driver.get(url_goodsno)
    time.sleep(1)
    if page_no == goods_page:
        for num in range(1, (num_goods%12)+1):
            goodsno_num = re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div[3]/div/div/div/div[2]/div[3]/a[{num}]').get_attribute('href'))[0]
            goodsno.append(goodsno_num)
    else:
        for num in range(1, 10):
            goodsno_num = re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div[3]/div/div/div/div[2]/div[3]/a[{num}]').get_attribute('href'))[0]
            goodsno.append(goodsno_num)
# 제품별 리뷰 추출
review = []
for good in goodsno:
    url = f'https://www.kurly.com/goods/{good}'
    driver.get(url)
    # 최근순
    driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[1]/div/button[2]').click()
    # 리뷰 수 추출
    review_tot_temp = re.findall(r'\d+', driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/nav/ul/li[3]/a/span[2]').text)
    review_tot = int(''.join(review_tot_temp))
    if review_tot%10 == 0:
        page_click = review_tot/10 - 1
    else:
        page_click = int(review_tot/10)
    # 크롤링
    for _ in range(page_click):
        for n in range(4,14):
            grade = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/div/div/span[1]').text
            name = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/div/div/span[2]').text
            menu = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/div/h3').text
            review_txt = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/p').text
            review_date = driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/footer/div/span').text
            try:
                like = int(re.findall(r'\d+', driver.find_element(By.XPATH, f'/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[{n}]/article/div/footer/button/span[2]').text)[0])
            except:
                like = 0
            review.append([good, grade, name, menu, review_txt, review_date, like])
        driver.find_element(By.XPATH, '/html/body/div/div/div[3]/div[2]/div/div[3]/section/div[2]/div[14]/button[2]').click()
        time.sleep(1)

# %%
review_df.to_csv('C:/Users/NT550-048/Desktop/잇더/data/review_5131316.csv', doublequote=False, escapechar='"', quoting=csv.QUOTE_NONE)

# %%
review_df['ReviewText']
# Out:
# 0       얼마전 옆에 언니를 통해서 알게된 문어솥밥.\n너무 맛있어서 마켓컬리에서 주문해보았...
# 1       요즘 같이 추운 날씨에는 집 밖을 나가는 데에도 큰 용기가 필요하죠ㅠㅠ\n배달 음식...
# 2                                          간단한 한끼대용으로 좋네요
# 3                                            맛있어서 재구매했어요!
# 4                                          아침대용으로 간단하고좋아요
#                               ...
# 9852    후기보고 걱정했는데,\n비린내 안나고 맛있게 먹었어요.\n달래장 해서 같이 먹었는데...
# 9853    담백하니 정말 맛있고 잘 차려낸 정식같은 한끼였어요\n도미살이 부드럽고 육수 풍미도...
# 9854    도미살도 크고 야채도 나름 많이 들었는데 맛이 미묘해요 약간 비린내도 있고.. 밥하...
# 9855                                   맛있는데  가시가 은근 있네요 .
# 9856    도미가 살짝 비려서 미나리 곁들이니 좀 낫더라구요..\n보양되는 아주 영양만점의 키...
# Name: ReviewText, Length: 9857, dtype: object
