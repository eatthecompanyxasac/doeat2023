# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
import urllib.request
import json

# %%
import requests
import websocket
import time
import json
url = 'https://smartstore.naver.com/i/v1/reviews/paged-reviews'

# %%
payload = {'merchantNo': "500179188",
           'originProductNo': "3820329999",
           'page': 3,
           'pageSize': 20,
           'sortType': "REVIEW_RANKING"}

# %%
res = requests.post(url,json=payload)
json.loads(res.text)
# Out:
# {'contents': [{'id': '4303670126',
#    'reviewType': 'NORMAL',
#    'reviewServiceType': 'SELLBLOG',
#    'reviewContentClassType': 'PHOTO',
#    'reviewScore': 5,
#    'reviewContent': '포장부터 정성이네요  잘먹을께요',
#    'createDate': '2023-08-01T13:06:02.565+00:00',
#    'repurchase': False,
#    'reviewRankingScore': -67.9885,
#    'writerMemberNo': 0,
#    'checkoutMerchantId': '',
#    'checkoutMerchantNo': 0,
#    'orderNo': '',
#    'productOrderNo': '2023072928217331',
#    'productNo': '3826902181',
#    'productName': '허니바이허니 천연 벌꿀 스틱 90포입 국산 아카시아 5종 선물 세트',
#    'productUrl': 'https://smartstore.naver.com/main/products/3826902181',
#    'largeCategorizeCategoryId': '50000006',
#    'middleCategorizeCategoryId': '50000023',
#    'smallCategorizeCategoryId': '50001905',
#    'productOptionContentNoDisplay': False,
#    'productOptionContent': '30포 선택1: 올인원 / 30포 선택2: 올인원 / 30포 선택3: 올인원',
#    'knowledgeShoppingMallProductId': '3826902181',
#    'originProductNo': 3820329999,
# ...

# %%
url_products = 'https://search.shopping.naver.com/api/product-zzim/products'

# %%
payload_product = {"params":[{"nvMid":"35528390094","chpid":'null',"isBook":'false'},{"nvMid":"82561609160","chpid":"5017088386","isBook":'false'},{"nvMid":"83068891672","chpid":"5524396185","isBook":'false'},{"nvMid":"41581259286","chpid":'null',"isBook":'false'},{"nvMid":"84023662754","chpid":"6479162421","isBook":'false'}]}

# %%
https://search.shopping.naver.com/api/graphql

# %%
res = requests.post(url_products)
json.loads(res.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[13], line 2
#       1 res = requests.post(url_products)
# ----> 2 json.loads(res.text)
#
# File c:\Users\NT550-048\anaconda3\envs\doeat\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\NT550-048\anaconda3\envs\doeat\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
url_products = 'https://search.shopping.naver.com/api/search/all?eq=&iq=&origQuery=%EA%BF%80%EC%8A%A4%ED%8B%B1&pagingIndex=1&pagingSize=40&productSet=total&query=%EA%BF%80%EC%8A%A4%ED%8B%B1&sort=review&viewType=list&xq='

# %%
res = requests.get(url_products)
json.loads(res.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[15], line 2
#       1 res = requests.get(url_products)
# ----> 2 json.loads(res.text)
#
# File c:\Users\NT550-048\anaconda3\envs\doeat\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\NT550-048\anaconda3\envs\doeat\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...
